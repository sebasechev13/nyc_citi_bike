# %%
import glob
import pandas as pd

# %%
# Merging csv files (without repeating header)
all_years_files = glob.glob("data/*.csv") 
df = pd.concat((pd.read_csv(f, header = 0) for f in all_years_files))
df
# Out:
#        tripduration                 starttime                  stoptime  \
# 0               142  2019-02-01 15:35:02.0820  2019-02-01 15:37:24.1360
# 1               223  2019-02-01 17:00:46.8900  2019-02-01 17:04:30.5500
# 2               106  2019-02-01 17:08:01.3260  2019-02-01 17:09:47.4400
# 3               370  2019-02-01 17:09:31.2100  2019-02-01 17:15:41.6550
# 4               315  2019-02-01 17:19:53.2490  2019-02-01 17:25:09.1400
# ...             ...                       ...                       ...
# 36130           792  2019-05-31 23:51:00.1170  2019-06-01 00:04:12.4530
# 36131           779  2019-05-31 23:51:22.7840  2019-06-01 00:04:22.3990
# 36132           347  2019-05-31 23:55:38.3850  2019-06-01 00:01:26.2030
# 36133           552  2019-05-31 23:56:11.9740  2019-06-01 00:05:24.8810
# 36134           520  2019-05-31 23:56:25.0240  2019-06-01 00:05:05.4860
#
#        start station id  start station name  start station latitude  \
# ...

# %%
# Export file as a CSV
df.to_csv("data/2019-citibike-tripsdata.csv")
